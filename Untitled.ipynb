# %%
import os
a = os.listdir('./preprocessed_data/validation/images')
len(a)
# Out:
# 2000

# %%
print(a[0])
# Out:
# BHrwBEaSlO4SjJZSAY0Q0Q.jpg

# %%
from PIL import Image
i = Image.open('./preprocessed_data/validation/images/'+a[0])
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=512x288 at 0x7F415005D5C0>

# %%
i.size
# Out:
# (512, 288)

# %%
training_color_path = '/home/ec2-user/SageMaker/preprocessed_data/training/labels'
validation_color_path = '/home/ec2-user/SageMaker/preprocessed_data/validation/labels'

training_class_path = '/home/ec2-user/SageMaker/preprocessed_data/training/class_labels'
validation_class_path = '/home/ec2-user/SageMaker/preprocessed_data/validation/class_labels'

# %%
b = os.listdir('./preprocessed_data/training/class_labels')
len(b)
# Out:
# 18000

# %%
i = Image.open(os.path.join(training_class_path, b[0]))
i
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=512x384 at 0x7F4139E51390>

# %%
i = Image.open(os.path.join('/home/ec2-user/SageMaker/preprocessed_data/training/labels', b[0]))
i
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=512x384 at 0x7F4139E51588>
